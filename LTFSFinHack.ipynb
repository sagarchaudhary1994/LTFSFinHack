# %%
# !git config --global user.email "sagarchaudhary1994@gmail.com"
# !git config --global user.name "sagarchaudhary1994"

# %%
# Mount Google Drive
from google.colab import drive # import drive from google colab
from os.path import join 

ROOT = "/content/drive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)

drive.mount(ROOT)           # we mount the google drive at /content/drive
# Out:
# /content/drive
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/MachineLearning/LTFSFinHack
# Out:
# /content/drive/My Drive/MachineLearning/LTFSFinHack

# %%
# !git add -u

# %%
# !git commit -m "First Commit From Notebook"
# Out:
# [develop a15887d] First Commit From Notebook
#  1 file changed, 1 insertion(+), 42 deletions(-)
#  rewrite LTFSFinHack.ipynb (100%)

# %%
# !git push origin develop
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.26 KiB | 644.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/sagarchaudhary1994/LTFSFinHack.git
#    1f60b09..a15887d  develop -> develop
