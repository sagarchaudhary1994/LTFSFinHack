# %%
# !git config --global user.email "sagarchaudhary1994@gmail.com"
# !git config --global user.name "sagarchaudhary1994"

# %%
# Mount Google Drive
from google.colab import drive # import drive from google colab
from os.path import join 

ROOT = "/content/drive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)

drive.mount(ROOT)           # we mount the google drive at /content/drive

# %%
# %cd /content/drive/My Drive/MachineLearning/LTFSFinHack

# %%
# !git status

# %%
# !git add -u

# %%
# !git commit -m "Commit From Notebook"

# %%
# !git push origin develop

# %%
# %pwd
# Out:
# '/content/drive/My Drive/MachineLearning/LTFSFinHack'

# %%
# %ls
# Out:
# LTFSFinHack.ipynb  README.md  sample_submission.csv  test.csv  train.csv

# %%
import pandas as pd
import numpy as np

# %%
train= pd.read_csv("train.csv")
test=pd.read_csv("test.csv")
